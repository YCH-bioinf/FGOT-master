# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as pl
import scanpy as sc
from anndata import AnnData
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
import sys
sys.path.insert(1, '/home/nas2/biod/yangchenghui/FGOT-master')
import FGOT
from FGOT import preprocess as pre
from FGOT import fgot_sparse_4dim, fgot_tol, align
from FGOT import metrics as mt

# %% [markdown]
# ## load data

# %%
data_path = "/home/nas2/biod/yangchenghui/BMMC/output_ych/"
RNA_data = pd.read_csv(data_path+'RNA_normalized.txt', sep='\t', index_col=0)
ATAC_data = pd.read_csv(data_path+'ATAC_normalized.txt', sep='\t', index_col=0)

# %%
cell1_cluster = pd.read_csv(data_path+"BMMC_RNA_label.txt", sep='\t')
cell2_cluster = pd.read_csv(data_path+"BMMC_agg_k5_atac_label.txt", sep='\t')
cell1_cluster = cell1_cluster.reset_index()
cell1_cluster = cell1_cluster.rename(columns={'index':'cell','x': 'cluster'})
cell2_cluster = cell2_cluster.reset_index()
cell2_cluster = cell2_cluster.rename(columns={'index':'cell','metas': 'cluster'})

# %%
X1 = RNA_data
X2 = ATAC_data
(n1, d1) = X1.shape
(n2, d2) = X2.shape
print("Dimensions of input datasets are: ", "X1 = ", X1.shape, " X2 = ", X2.shape)
basic_labels1 = np.array(cell1_cluster['cluster'])
basic_labels2 = np.array(cell2_cluster['cluster'])
print("Dimensions of basic_labels are: ", "basic_labels1 = ", basic_labels1.shape, " basic_labels2 = ", basic_labels2.shape)
cell_names1 = list(RNA_data.index)
cell_names2 = list(ATAC_data.index)
gene_names = list(RNA_data.columns)
peak_names = list(ATAC_data.columns)
# Out:
# Dimensions of input datasets are:  X1 =  (2379, 275)  X2 =  (1602, 604)
# Dimensions of basic_labels are:  basic_labels1 =  (2379,)  basic_labels2 =  (1602,)

# %% [markdown]
# ## compute feature relationship

# %%
feature_matrix = pd.read_csv(data_path+'feature_matrix_new.txt', sep='\t', index_col=0)
feature_matrix[feature_matrix == 0] = np.inf

# %%
feature_matrix
# Out:
#           chr8-48513065-48513907  chr14-99735992-99741482  \
# TNFRSF25                     inf                      inf
# EFHD2                        inf                      inf
# RCAN3                        inf                      inf
# LDLRAP1                      inf                      inf
# STMN1                        inf                      inf
# ...                          ...                      ...
# ALAS2                        inf                      inf
# ITM2A                        inf                      inf
# SH2D1A                       inf                      inf
# CD40LG                       inf                      inf
# MPP1                         inf                      inf
#
#           chr7-38271913-38273154  chr14-75083175-75085729  \
# TNFRSF25                     inf                      inf
# EFHD2                        inf                      inf
# RCAN3                        inf                      inf
# LDLRAP1                      inf                      inf
# STMN1                        inf                      inf
# ...                          ...                      ...
# ALAS2                        inf                      inf
# ITM2A                        inf                      inf
# SH2D1A                       inf                      inf
# CD40LG                       inf                      inf
# MPP1                         inf                      inf
#
#           chr17-34430582-34431414  chr10-73397511-73398744  \
# TNFRSF25                      inf                      inf
# EFHD2                         inf                      inf
# RCAN3                         inf                      inf
# LDLRAP1                       inf                      inf
# STMN1                         inf                      inf
# ...                           ...                      ...
# ALAS2                         inf                      inf
# ITM2A                         inf                      inf
# SH2D1A                        inf                      inf
# CD40LG                        inf                      inf
# MPP1                          inf                      inf
#
#           chr12-6444678-6447404  chr14-99727057-99729681  \
# TNFRSF25                    inf                      inf
# EFHD2                       inf                      inf
# RCAN3                       inf                      inf
# LDLRAP1                     inf                      inf
# STMN1                       inf                      inf
# ...                         ...                      ...
# ALAS2                       inf                      inf
# ITM2A                       inf                      inf
# SH2D1A                      inf                      inf
# CD40LG                      inf                      inf
# MPP1                        inf                      inf
#
#           chr17-3817040-3818120  chr1-228327166-228329275  ...  \
# TNFRSF25                    inf                       inf  ...
# EFHD2                       inf                       inf  ...
# RCAN3                       inf                       inf  ...
# LDLRAP1                     inf                       inf  ...
# STMN1                       inf                       inf  ...
# ...                         ...                       ...  ...
# ALAS2                       inf                       inf  ...
# ITM2A                       inf                       inf  ...
# SH2D1A                      inf                       inf  ...
# CD40LG                      inf                       inf  ...
# MPP1                        inf                       inf  ...
#
#           chr1-145744037-145744638  chr1-182118302-182119022  \
# TNFRSF25                       inf                       inf
# EFHD2                          inf                       inf
# RCAN3                          inf                       inf
# LDLRAP1                        inf                       inf
# STMN1                          inf                       inf
# ...                            ...                       ...
# ALAS2                          inf                       inf
# ITM2A                          inf                       inf
# SH2D1A                         inf                       inf
# CD40LG                         inf                       inf
# MPP1                           inf                       inf
#
#           chr22-39363666-39364245  chr19-14620561-14629959  \
# TNFRSF25                      inf                      inf
# EFHD2                         inf                      inf
# RCAN3                         inf                      inf
# LDLRAP1                       inf                      inf
# STMN1                         inf                      inf
# ...                           ...                      ...
# ALAS2                         inf                      inf
# ITM2A                         inf                      inf
# SH2D1A                        inf                      inf
# CD40LG                        inf                      inf
# MPP1                          inf                      inf
#
#           chr6-135644264-135644734  chr6-138279886-138280709  \
# TNFRSF25                       inf                       inf
# EFHD2                          inf                       inf
# RCAN3                          inf                       inf
# LDLRAP1                        inf                       inf
# STMN1                          inf                       inf
# ...                            ...                       ...
# ALAS2                          inf                       inf
# ITM2A                          inf                       inf
# SH2D1A                         inf                       inf
# CD40LG                         inf                       inf
# MPP1                           inf                       inf
#
#           chr17-62008536-62010304  chrX-153962206-153963124  \
# TNFRSF25                      inf                       inf
# EFHD2                         inf                       inf
# RCAN3                         inf                       inf
# LDLRAP1                       inf                       inf
# STMN1                         inf                       inf
# ...                           ...                       ...
# ALAS2                         inf                       inf
# ITM2A                         inf                       inf
# SH2D1A                        inf                       inf
# CD40LG                        inf                       inf
# MPP1                          inf                       1.0
#
#           chr5-54198542-54199109  chr15-75639149-75640672
# TNFRSF25                     inf                      inf
# EFHD2                        inf                      inf
# RCAN3                        inf                      inf
# LDLRAP1                      inf                      inf
# STMN1                        inf                      inf
# ...                          ...                      ...
# ALAS2                        inf                      inf
# ITM2A                        inf                      inf
# SH2D1A                       inf                      inf
# CD40LG                       inf                      inf
# MPP1                         inf                      inf
#
# [275 rows x 604 columns]

# %% [markdown]
# ## compute cost
# Calculate the similarity between cells through MNN pairs between RNA and gene activity score.

# %%
cell_Cor = pd.read_table(data_path+'cell_Cor_scVIlatent.txt',index_col=0)
cell_Cor
# Out:
#                     Agg_atac_1-1  Agg_atac_2-1  Agg_atac_3-1  Agg_atac_4-1  \
# AAACCTGAGCTTTGGT.1             0             0             0             1
# AAACCTGCACAGGCCT.1             0             0             0             0
# AAACCTGCATGCCTTC.1             0             0             0             0
# AAACCTGGTGTGTGCC.1             0             0             0             0
# ...                             ...              ...              ...
# TTTGTCAAGCCCAATT.1                0                0                0
# TTTGTCAAGTCACGCC.1                0                0                0
# TTTGTCACACATCCAA.1                0                0                0
# TTTGTCACAGGTCTCG.1                0                0                0
# TTTGTCATCGTAGGAG.1                0                0                0
#
# [2379 rows x 1602 columns]

# %%
S_new = pre.smooth_cell_similarity_byLaplacian1(cell_Cor,X1,X2,n_neighbors=30)
S_new = S_new/np.max(S_new) + cell_Cor/np.max(cell_Cor)

# %%
cost = np.array(np.exp(np.max(S_new) - S_new))
cost = cost - np.min(cost)
cost = pd.DataFrame(cost, index = cell_names1, columns=cell_names2)

# %%
sorted_cols = np.argsort(basic_labels1)
sorted_cost = cost.iloc[sorted_cols,: ]
sorted_rows = np.argsort(basic_labels2)
sorted_cost = sorted_cost.iloc[:, sorted_rows]
sns.heatmap(sorted_cost)
pl.title('cost across modality')
# Out:
# Text(0.5, 1.0, 'cost across modality')

# %%
sorted_cost.index = list(cell1_cluster.iloc[sorted_cols]["cluster"])
sorted_cost.columns = list(cell2_cluster.iloc[sorted_rows]["cluster"])
sns.heatmap(sorted_cost)
pl.title('cost across modality')
# Out:
# Text(0.5, 1.0, 'cost across modality')

# %% [markdown]
# ## scale

# %%
scaler = StandardScaler()
X1, X2 = scaler.fit_transform(X1), scaler.fit_transform(X2)
X1 = pd.DataFrame(X1,index= cell_names1,columns=gene_names)
X2 = pd.DataFrame(X2,index= cell_names2,columns=peak_names)

# %% [markdown]
# ## solve the feature-guided optimal transport

# %%
P_4dim = fgot.fgot_sparse_4dim(X1, X2, feature_matrix, cost,\
    minibatch=0,device='cuda:5',eps_p = 5e-2, rho=100)
# Out:
# minibatch = 0 and device =  cuda:5

# %%
P = fgot_tol(P_4dim)
P.shape
# Out:
# 100%|██████████| 775/775 [00:06<00:00, 124.57it/s]
# (2379, 1602)

# %%
sns.heatmap(P, cmap="RdBu_r")
pl.title('optimal transport matrix')
# Out:
# Text(0.5, 1.0, 'optimal transport matrix')

# %%
X1_aligned, X2_aligned = align(X1, X2, P)

# %%
data_aligned = np.concatenate((X1_aligned,X2_aligned), axis=0)
adata_aligned = AnnData(data_aligned)
adata_aligned.obs['batch'] = np.array(['RNA'] * n1 + ['ATAC'] * n2)
adata_aligned.obs['label'] = np.concatenate((basic_labels1, basic_labels2),axis=0)
sc.tl.pca(adata_aligned)
sc.pp.neighbors(adata_aligned, n_neighbors=15, n_pcs=40)
sc.tl.umap(adata_aligned)

# %%
sc.pl.umap(adata_aligned, color=['batch','label'],s = 80)
# Out:
# /home/yangchenghui/anaconda3/envs/py310/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/yangchenghui/anaconda3/envs/py310/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/yangchenghui/anaconda3/envs/py310/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/yangchenghui/anaconda3/envs/py310/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ajust

# %%
X2_adjust,_,_ = FGOT.fgot.adjust(X1_aligned, X2_aligned)

# %%
data_aligned = np.concatenate((X1_aligned,X2_adjust), axis=0)
adata_aligned = AnnData(data_aligned)
adata_aligned.obs['batch'] = np.array(['RNA'] * n1 + ['ATAC'] * n2)
adata_aligned.obs['label'] = np.concatenate((basic_labels1, basic_labels2),axis=0)
sc.tl.pca(adata_aligned)
sc.pp.neighbors(adata_aligned, n_neighbors=15, n_pcs=40)
sc.tl.umap(adata_aligned)
sc.pl.umap(adata_aligned, color=['batch', 'label'],s = 80)
# Out:
# /home/yangchenghui/anaconda3/envs/py310/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/yangchenghui/anaconda3/envs/py310/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/yangchenghui/anaconda3/envs/py310/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/yangchenghui/anaconda3/envs/py310/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
